# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
wavelengths = np.arange(380, 710, 10)
scattering_coeffs = np.array([
    0.0073, 0.0066, 0.0058, 0.0052, 0.0047, 0.0043, 0.0039, 0.0035, 0.0032, 0.0029, 0.0027,
    0.0024, 0.0022, 0.0020, 0.0018, 0.0017, 0.0016, 0.0015, 0.0013, 0.0013, 0.0012, 0.0011,
    0.00101, 0.00094, 0.00088, 0.00082, 0.00076, 0.00071, 0.00067, 0.00063, 0.00059, 0.00055, 0.00052
])

print(wavelengths.shape)
print(scattering_coeffs.shape)
# Out:
# (33,)
# (33,)

# %%
# Plot the data points
plt.scatter(wavelengths, scattering_coeffs, label='Data')

# Add labels and title
plt.xlabel('Wavelength')
plt.ylabel('Scattering Coefficient')
plt.title('Scattering Coefficient vs Wavelength')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Fitting procedure
import scipy.optimize as opt
# Out:
# R² = 0.0
# /var/folders/2y/rhmx4lpx7yj6c8p50ldw1x_c0000gp/T/ipykernel_65369/2744615018.py:8: OptimizeWarning: Covariance of the parameters could not be estimated

# %%
# Plot original data in red
plt.scatter(wavelengths, scattering_coeffs, label='Data', color='red')

# Plot the fit
plt.plot(wavelengths, exp_func(wavelengths, alpha, beta, gamma), '--', label="Fitted")

# Add labels and title
plt.xlabel('Wavelength')
plt.ylabel('Scattering Coefficient')
plt.title('Fitted Exponential Curve')

# Print the parameters
print(f"alpha = {alpha}")
print(f"beta = {beta}")
print(f"gamma = {gamma}")
# Out:
# alpha = 1.0
# beta = 1.0
# gamma = 0.0023115151493386943
