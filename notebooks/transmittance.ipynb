# %% [markdown]
# // Upwelling and downwelling transmittance tabulation
#         /*
#         std::vector<ScalarFloat> transmittance_angles = {   0.00000000f, 0.08726646f, 0.17453293f, 0.26179939f, 0.34906585f,
#                                                             0.43633231f, 0.52359878f, 0.61086524f, 0.69813170f, 0.78539816f,
#                                                             0.87266463f, 0.95993109f, 1.04719755f, 1.13446401f, 1.22173048f,
#                                                             1.30899694f, 1.39626340f, 1.48352986f, 1.57079633f };
#         std::vector<ScalarFloat> up_transmittance = {   0.9755f, 0.9755f, 0.9755f, 0.9755f, 0.9750f,
#                                                         0.9750f, 0.9750f, 0.9725f, 0.9725f, 0.9700f,
#                                                         0.9655f, 0.9650f, 0.9625f, 0.9600f, 0.9550f,
#                                                         0.9455f, 0.9400f, 0.9350f, 0.9300f };
#         std::vector<ScalarFloat> down_transmittance = { 0.9300f, 0.9300f, 0.9200f, 0.9150f, 0.9100f,
#                                                         0.9000f, 0.8900f, 0.8850f, 0.8750f, 0.8700f,
#                                                         0.8650f, 0.8600f, 0.8600f, 0.8550f, 0.8600f,
#                                                         0.8650f, 0.8650f, 0.8700f, 0.8800f };
#         */

# %%
import numpy as np

# %%
angles = np.array([0.00000000, 0.08726646, 0.17453293, 0.26179939, 0.34906585, 
                   0.43633231, 0.52359878, 0.61086524, 0.69813170, 0.78539816, 
                   0.87266463, 0.95993109, 1.04719755, 1.13446401, 1.22173048, 
                   1.30899694, 1.39626340, 1.48352986, 1.57079633])
down = np.array([
    0.9755, 0.9755, 0.9755, 0.9755, 0.9750, 
    0.9750, 0.9750, 0.9725, 0.9725, 0.9700,
    0.9655, 0.9650, 0.9625, 0.9600, 0.9550,
    0.9455, 0.9400, 0.9350, 0.9300
])

up = np.array([
    0.9300, 0.9300, 0.9200, 0.9150, 0.9100,
    0.9000, 0.8900, 0.8850, 0.8750, 0.8700, 
    0.8650, 0.8600, 0.8600, 0.8550, 0.8600, 
    0.8650, 0.8650, 0.8700, 0.8800
])

# %%
# Downwelling tabulated data
down_x = [0.02975054413543623, 5.020469123168808, 25.06263598345881, 30.017135507018104, 35.00736448367945, 55.01450461427196, 10.007985126686341, 15.083168754935985, 20.08830468381853, 40.16372418521093, 45.07987344297086, 50.01705256261626, 60.01139794322076, 65.05291996838666, 70.11053551152244, 75.01921977311595, 80.00248487603872, 85.05430583110089, 88.82314969039562]
down_y = [0.9780683478771868, 0.978029174055603, 0.9756693839967341, 0.9745382429456244, 0.9732677345846421, 0.9646858114872173, 0.9777354963415015, 0.9773141482094939, 0.9765820584709712, 0.9716018273966156, 0.9697201513518503, 0.9673466086082625, 0.9614511475386391, 0.9578261511139309, 0.953225181299794, 0.9481251251352111, 0.942188848860067, 0.935132076152414, 0.92912925882252]

# Upwelling tabulated data
up_x = [0.035159773883192996, 5.006828732305758, 10.011379113415812, 15.03218729219628, 20.05980631540122, 25.094881760701195, 30.099921704878096, 35.07942367237019, 40.005660102226685, 45.0464058713998, 50.02242709928476, 55.03929187446086, 60.04530556495752, 65.05789338806612, 70.03127312731569, 75.06914607585477, 80.08241175551747, 85.05928837381593, 88.9487862426968]
up_y = [0.9350230725506344, 0.932385121621535, 0.9275188028895589, 0.920337736119776, 0.9118264288732105, 0.9029461621937295, 0.8945211897586579, 0.8863888199598756, 0.8791320171804307, 0.8727345198300839, 0.867724239086939, 0.8643523968367044, 0.8622957447646509, 0.8621000606005421, 0.8631169399305904, 0.8651841756633303, 0.8681728863684854, 0.8740256053046701, 0.8796063287035559]

up_x = [0.035159773883192996, 5.006828732305758, 10.011379113415812, 15.03218729219628, 20.05980631540122, 25.094881760701195, 30.099921704878096, 35.07942367237019, 40.005660102226685, 45.0464058713998, 50.02242709928476, 55.03929187446086, 60.04530556495752, 65.05789338806612, 70.04698218396612, 75.06914607585477, 80.08241175551747, 85.05928837381593, 88.9487862426968, 2.4720002877124485, 7.5018250346251545, 12.504863688023299, 17.513782478037513, 22.5178379162668, 27.508266285833226, 32.52651905300104, 37.51608665234004, 42.50723591697193, 47.4938015801428, 52.50967646955736, 57.502837784595854, 62.4899252897171, 67.52396781074417, 72.52745298869779, 77.5039637796496, 82.5048558872931, 87.00608163754649]
up_y = [0.9350230725506344, 0.932385121621535, 0.9275188028895589, 0.920337736119776, 0.9118264288732105, 0.9029461621937295, 0.8945211897586579, 0.8863888199598756, 0.8791320171804307, 0.8727345198300839, 0.867724239086939, 0.8643523968367044, 0.8622957447646509, 0.8621000606005421, 0.8631340494249762, 0.8651841756633303, 0.8681728863684854, 0.8740256053046701, 0.8796063287035559, 0.9338804460074228, 0.9305148267679781, 0.9240766603008875, 0.9162867075070046, 0.9077016931642706, 0.8988547975694147, 0.890360342417762, 0.8826869007383031, 0.8758391511449896, 0.8702760368982903, 0.8658066432949207, 0.8629755216318612, 0.8620119391338822, 0.8624740771760462, 0.8640460611814701, 0.8662731268458358, 0.8708275985456249, 0.8766504894252253]

# Sort up_x and up_y
up_x, up_y = zip(*sorted(zip(up_x, up_y)))

# %%
# Transform down_x and up_x to radians
down_x = np.array(down_x) * np.pi / 180
up_x = np.array(up_x) * np.pi / 180

# %%
# Fit a polynomial to the upwelling data
up_fit = np.polyfit(angles, up, 4)

# Fit a polynomial to the downwelling data
down_fit = np.polyfit(angles, down, 4)

# %%
# Visualize up 
import matplotlib.pyplot as plt

plt.plot(angles, down, label='down')

# Plot the fit
x = np.linspace(0, np.pi / 2, 100)
y = np.polyval(down_fit, x)
plt.plot(x, y, label='down fit', color='red')

# Plot the tabulated data as a line
plt.plot(down_x, down_y, label='down tabulated', color='green')

plt.xlabel('Angle (radian)')
plt.ylabel('Downwelling Transmittance')
plt.title('Downwelling Transmittance vs. Angle')

# y-limit
plt.ylim(0.9, 1.0)

plt.show()

# %%
# Visualize down
plt.plot(angles, up, label='up')

# Plot the fit
x = np.linspace(0, np.pi / 2, 100)
y = np.polyval(up_fit, x)
plt.plot(x, y, label='up fit', color='red')

# Plot the tabulated data
plt.plot(up_x, up_y, label='up tabulated', color='green')

plt.xlabel('Angle (radian)')
plt.ylabel('Upwelling Transmittance')
plt.title('Upwelling Transmittance vs. Angle')

# y-limit
plt.ylim(0.8, 1.0)

plt.show()

# %%
# Print the coefficients
print('Downwelling fit coefficients:', down_fit)
print('Upwelling fit coefficients:', up_fit)
# Out:
# Downwelling fit coefficients: [ 0.00882913 -0.03803999  0.02232457 -0.00533469  0.97575765]
# Upwelling fit coefficients: [-0.03694741  0.17051226 -0.18538372 -0.01917329  0.93060225]
